# %%
from elastic_methods import ElasticMethods
import requests
import logging
import urllib3
import sys
import os
sys.path.append(os.path.abspath('../vault'))
from vault_methods import VaultMethods

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

logging.basicConfig(format='%(asctime)s %(message)s',
                    datefmt='%m/%d/%Y %I:%M:%S %p',
                    level=logging.INFO)

if __name__ == '__main__':
    vault_session = VaultMethods()
    vault_session.authenticate()
    elastic_secret = vault_session.retrieve_elastic_secret()
    if elastic_secret:
        fqdn = input("Enter the Elastic Security FQDN-> ")
        session = ElasticMethods(fqdn, elastic_secret)
        session._get_agents()
# Out:
# Enter the Vault FQDN->  vault.internal.subterfuge.biz
# Enter the Vault username->  robert.gaines
# Enter the Vault password->  ········
# Enter the Elastic Security FQDN->  nsm.internal.subterfuge.biz
#                                       id       type  active  \
# 0   21d4ce34-c442-48f2-b955-db72e2343dc5  PERMANENT    True
# 1   104ae1ea-ea4c-41c1-a979-1d506f3a9864  PERMANENT    True
# 2   9bad562d-1302-47f5-9701-3f2dc5000d97  PERMANENT    True
# 3   b1e3552d-333b-4bd0-807a-283d6dd0775d  PERMANENT    True
# 4   a4032047-1f3f-481c-97f7-a231d630decb  PERMANENT    True
# 5   c6004c8d-f229-4253-854f-f00873780523  PERMANENT    True
# 6   66849642-4e47-43dc-811e-3ee1d172d521  PERMANENT    True
# 7   7994e481-049b-4c51-85ca-56d738f68d16  PERMANENT    True
# 8   678f3380-92e1-460d-b434-67176b7ba949  PERMANENT    True
# 9   748ae389-a219-4576-8a87-5fbfa2d6a112  PERMANENT    True
# 10  70ec403d-4860-433f-a588-bb9fb53e927c  PERMANENT    True
# 11  f6d93383-b967-4cdc-be20-03db693348ad  PERMANENT    True
# 12  76f782c1-0903-4e53-b3d7-0b58ba73d4e7  PERMANENT    True
# 13  983c0a27-c899-412d-86d4-7472fcd41ad8  PERMANENT    True
# 14  0511a7a0-8795-43b9-9efe-a0d6fdfb978b  PERMANENT    True
# 15  992cbc5a-9b99-44e5-8900-0073235d450a  PERMANENT    True
# 16  5c733b06-3b45-4dcf-ae94-2f04254d33dc  PERMANENT    True
# 17  10e653eb-a7cb-4e28-86f9-661072f6e584  PERMANENT    True
# 18  bb110d9b-172e-4dad-9826-380b87ab98e0  PERMANENT    True
# 19  f12925b0-2d4e-4fb3-bc65-24ca864db9fb  PERMANENT    True
# 20  0d8c6ec2-7f93-4ff1-bc0e-63d665cf245d  PERMANENT    True
# 21  fa2d50f5-2616-483b-97e9-140ec76f7815  PERMANENT    True
# 22  de86d989-13f2-4098-8370-faafc0c7b78b  PERMANENT    True
# 23  ab3bf1af-66e5-485f-800e-440c791b71f5  PERMANENT    True
# 24  e8f211b2-1e04-47ec-9299-19ca56ae773c  PERMANENT    True
# 25  5134b9f4-5f41-4989-9d4f-06067dd864ec  PERMANENT    True
# 26  4cfb7445-f2ff-4074-8f62-2070e14f18cf  PERMANENT    True
# 27  dad99fa5-8b19-4654-a18f-711468871996  PERMANENT    True
# 28  dd054ef4-f1d2-4d98-ba68-a22dfc1f818a  PERMANENT    True
# 29  d3a5b42f-b06b-4aff-a84e-0d385558dd34  PERMANENT    True
# 30  7382e546-c57b-45bd-a66f-adcc7f0ad4f7  PERMANENT    True
# 31  94e631b4-9cd5-4f02-b4f3-8588eee78bb5  PERMANENT    True
# 32  42fd8984-3fda-4d7f-aa62-4f849cace21f  PERMANENT    True
# 33  af54000c-c13e-4c6d-9bf8-ed03cd3adc35  PERMANENT    True
#
#              enrolled_at           upgraded_at  upgrade_started_at  \
# 0   2025-07-15T03:24:41Z  2025-07-15T03:43:01Z                 NaN
# 1   2025-07-10T01:44:46Z                   NaN                 NaN
# 2   2025-07-10T01:40:29Z                   NaN                 NaN
# 3   2025-07-03T03:54:55Z                   NaN                 NaN
# 4   2025-05-26T13:47:48Z                   NaN                 NaN
# 5   2025-03-24T00:34:49Z  2025-05-18T01:52:24Z                 NaN
# 6   2025-02-26T20:34:54Z  2025-05-18T01:52:16Z                 NaN
# 7   2025-02-26T20:34:54Z  2025-05-17T20:31:54Z                 NaN
# 8   2024-12-31T17:44:40Z  2025-05-26T22:19:01Z                 NaN
# 9   2024-12-30T21:04:13Z  2025-05-18T20:28:17Z                 NaN
# 10  2024-12-16T04:59:19Z  2025-05-18T20:47:44Z                 NaN
# 11  2024-12-16T04:59:15Z  2025-05-18T20:48:22Z                 NaN
# 12  2024-12-16T04:21:45Z  2025-05-26T05:08:01Z                 NaN
# 13  2024-12-01T03:30:53Z  2025-05-18T02:00:20Z                 NaN
# 14  2024-11-24T23:31:34Z  2025-05-18T02:03:34Z                 NaN
# 15  2024-11-24T23:22:59Z  2025-05-18T02:10:26Z                 NaN
# 16  2024-11-24T23:20:32Z  2025-05-17T22:04:50Z                 NaN
# 17  2024-11-24T20:02:02Z  2025-05-18T21:23:17Z                 NaN
# 18  2024-11-24T20:01:50Z  2025-05-18T01:51:09Z                 NaN
# 19  2024-11-24T20:01:49Z  2025-05-26T05:13:03Z                 NaN
# 20  2024-11-24T20:01:48Z  2025-05-26T05:13:16Z                 NaN
# 21  2024-11-24T18:25:12Z  2025-05-17T20:32:22Z                 NaN
# 22  2024-11-24T17:54:52Z  2025-05-26T05:12:55Z                 NaN
# 23  2024-10-30T14:12:39Z  2025-05-26T19:31:09Z                 NaN
# 24  2024-10-30T03:28:53Z  2025-06-01T22:41:04Z                 NaN
# 25  2024-10-29T02:01:36Z  2025-06-01T22:41:19Z                 NaN
# 26  2024-10-28T00:06:41Z  2025-05-26T05:42:11Z                 NaN
# 27  2024-10-28T00:06:31Z  2025-05-26T13:14:30Z                 NaN
# 28  2024-10-28T00:05:59Z  2025-05-26T13:18:06Z                 NaN
# 29  2024-10-28T00:05:58Z  2025-05-18T01:49:14Z                 NaN
# 30  2024-10-28T00:05:57Z  2025-05-18T01:58:09Z                 NaN
# 31  2024-10-28T00:05:57Z  2025-05-26T13:15:00Z                 NaN
# 32  2024-10-27T23:55:11Z  2025-05-17T20:16:30Z                 NaN
# 33  2024-10-20T04:53:08Z  2025-05-17T19:56:05Z                 NaN
#
#     upgrade_details     access_api_key_id  \
# 0               NaN  9XQcDJgB8Pxx7cAA-JP2
# 1               NaN  FPgB8pcB8Pxx7cAAsDJh
# 2               NaN  6_H98ZcB8Pxx7cAAw2s9
# 3               NaN  ahJszpcB8Pxx7cAAUx9B
# 4               NaN  3k3ZDJcByl2n126aedA2
# 5               NaN  r9CSxZUBRxaIxfso1160
# 6               NaN  p4D4Q5UBH557JrKpM8he
# 7               NaN  pYD4Q5UBH557JrKpM8hd
# 8               NaN  K-XRHZQBB9p5c4-73Ivn
# 9               NaN  FDliGZQB72VlzI1oMwDZ
# 10              NaN  YYvVzZMBULgSSVuAxf8A
# 11              NaN  _ovVzZMBULgSSVuAt_By
# 12              NaN  C3SzzZMBULgSSVuAYqA6
# 13              NaN  KUFFgJMBaHhpeRYTa5ue
# 14              NaN  MbSEYJMBWkMK-slTKkTq
# 15              NaN  pa18YJMBWkMK-slTUMwf
# 16              NaN  ZKt6YJMBWkMK-slTEdMx
# 17              NaN  YhnEX5MBWkMK-slTVNnA
# 18              NaN  -BnEX5MBWkMK-slTJml2
# 19              NaN  GhnEX5MBWkMK-slTI2J3
# 20              NaN  oRnEX5MBWkMK-slTHVvm
# 21              NaN  1tBrX5MBWkMK-slTrVT8
# 22              NaN  iLxPX5MBWkMK-slT5sez
# 23              NaN  mYrF3ZIBWkMK-slTd6Hx
# 24              NaN  fTp425IBWkMK-slTF1QF
# 25              NaN  qD4B1pIBWkMK-slT0W84
# 26              NaN  BkZy0JIBWkMK-slTP6pf
# 27              NaN  aUZy0JIBWkMK-slTGJLV
# 28              NaN  TEVx0JIBWkMK-slTnI5F
# 29              NaN  HUVx0JIBWkMK-slTmI6G
# 30              NaN  b0Vx0JIBWkMK-slTk4x1
# 31              NaN  EUVx0JIBWkMK-slTlY5s
# 32              NaN  dUFn0JIBWkMK-slTtyYx
# 33              NaN  Yu9FqJIBWkMK-slTnwTc
#
#                                policy_id          last_checkin  ...  \
# 0   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:52Z  ...
# 1   238151fa-4336-47fd-b17b-1e214177c6aa  2025-07-23T03:53:31Z  ...
# 2   08e2216b-a8b2-4ddb-9f8b-8ca978ae6acb  2025-07-23T02:02:25Z  ...
# 3   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:32Z  ...
# 4   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:59Z  ...
# 5   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:32Z  ...
# 6   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:33Z  ...
# 7   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:58Z  ...
# 8   07c2d755-ea95-4629-8a2b-5f061ddd715c  2025-07-22T23:03:17Z  ...
# 9   73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:35Z  ...
# 10  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:31Z  ...
# 11  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:47Z  ...
# 12  08e2216b-a8b2-4ddb-9f8b-8ca978ae6acb  2025-07-21T02:35:08Z  ...
# 13  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:59Z  ...
# 14  f1c7b16c-1e0d-4655-8042-e3a25c0e1abf  2025-07-23T03:53:56Z  ...
# 15  f1c7b16c-1e0d-4655-8042-e3a25c0e1abf  2025-07-23T03:53:38Z  ...
# 16  f1c7b16c-1e0d-4655-8042-e3a25c0e1abf  2025-07-23T03:53:37Z  ...
# 17  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:33Z  ...
# 18  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:54Z  ...
# 19  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:41Z  ...
# 20  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:52Z  ...
# 21  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:52Z  ...
# 22  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:32Z  ...
# 23  9c253c21-d2d2-40f2-9fa4-7ce23dd6da53  2025-07-23T03:53:55Z  ...
# 24  9c253c21-d2d2-40f2-9fa4-7ce23dd6da53  2025-07-23T03:53:47Z  ...
# 25  07c2d755-ea95-4629-8a2b-5f061ddd715c  2025-07-23T03:53:54Z  ...
# 26  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:52Z  ...
# 27  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:42Z  ...
# 28  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:59Z  ...
# 29  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:57Z  ...
# 30  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:55Z  ...
# 31  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:34Z  ...
# 32  73dd19e5-f40f-4b24-943e-8c6da2d52c11  2025-07-23T03:53:39Z  ...
# 33                   fleet-server-policy  2025-07-23T03:53:50Z  ...
#
#    policy_revision packages  \
# 0               39       []
# 1                9       []
# 2               27       []
# 3               39       []
# 4               39       []
# 5               39       []
# 6               39       []
# 7               39       []
# 8               31       []
# 9               39       []
# 10              39       []
# 11              39       []
# 12              27       []
# 13              39       []
# 14              30       []
# 15              30       []
# 16              30       []
# 17              39       []
# 18              39       []
# 19              39       []
# 20              39       []
# 21              39       []
# 22              39       []
# 23              34       []
# 24              34       []
# 25              31       []
# 26              39       []
# 27              39       []
# 28              39       []
# 29              39       []
# 30              39       []
# 31              39       []
# 32              39       []
# 33              66       []
#
#                                                  sort  \
# 0   [1752549881000, res-phy-prd-cda.identity.subte...
# 1                    [1752111886000, res-phy-prd-lnp]
# 2                    [1752111629000, res-phy-prd-mtp]
# 3   [1751514895000, res-vrt-prd-jpr.identity.subte...
# 4   [1748267268000, res-vrt-prd-fdm.identity.subte...
# 5   [1742776489000, res-phy-prd-rpi-10.identity.su...
# 6   [1740602094000, res-vrt-prd-atk.identity.subte...
# 7   [1740602094000, res-vrt-prd-msp.identity.subte...
# 8                    [1735667080000, res-phy-prd-ltp]
# 9   [1735592653000, res-phy-prd-rpi-4.identity.sub...
# 10  [1734325159000, res-vrt-prd-csr.identity.subte...
# 11  [1734325155000, res-vrt-prd-vms.identity.subte...
# 12                   [1734322905000, res-phy-prd-mbx]
# 13  [1733023853000, res-phy-prd-rpi-6.identity.sub...
# 14             [1732491094000, res-phy-prd-hvr-pmx-3]
# 15             [1732490579000, res-phy-prd-hvr-pmx-2]
# 16             [1732490432000, res-phy-prd-hvr-pmx-1]
# 17  [1732478522000, res-vrt-prd-cms.identity.subte...
# 18  [1732478510000, res-vrt-prd-vcr.identity.subte...
# 19  [1732478509000, res-vrt-prd-gsm.identity.subte...
# 20  [1732478508000, res-vrt-prd-vsr.identity.subte...
# 21  [1732472712000, res-vrt-prd-idm.identity.subte...
# 22  [1732470892000, res-vrt-prd-cds.identity.subte...
# 23                   [1730297559000, res-vrt-prd-swn]
# 24                   [1730258933000, res-vrt-prd-dss]
# 25                   [1730167296000, res-phy-prd-ept]
# 26  [1730074001000, res-phy-prd-rpi-12.identity.su...
# 27  [1730073991000, res-phy-prd-rpi-11.identity.su...
# 28  [1730073959000, res-phy-prd-rpi-9.identity.sub...
# 29  [1730073958000, res-phy-prd-rpi-5.identity.sub...
# 30  [1730073957000, res-phy-prd-rpi-7.identity.sub...
# 31  [1730073957000, res-phy-prd-rpi-8.identity.sub...
# 32  [1730073311000, res-phy-prd-rpi-1.identity.sub...
# 33  [1729399988000, res-phy-prd-nsm.identity.subte...
#
#                                               outputs  \
# 0   {'default': {'api_key_id': 'EnQdDJgB8Pxx7cAADq...
# 1   {'default': {'api_key_id': 'mfgB8pcB8Pxx7cAAxG...
# 2   {'default': {'api_key_id': 'EvH98ZcB8Pxx7cAA0p...
# 3   {'default': {'api_key_id': 'sRJszpcB8Pxx7cAAZT...
# 4   {'default': {'api_key_id': 'sk3ZDJcByl2n126ajP...
# 5   {'default': {'api_key_id': 'kdCSxZUBRxaIxfso_p...
# 6   {'default': {'api_key_id': 'FID4Q5UBH557JrKpPs...
# 7   {'default': {'api_key_id': 'EoD4Q5UBH557JrKpPc...
# 8   {'default': {'api_key_id': 'zOXSHZQBB9p5c4-7OP...
# 9   {'default': {'api_key_id': 'cDliGZQB72VlzI1oUA...
# 10  {'default': {'api_key_id': 'D4zVzZMBULgSSVuAzw...
# 11  {'default': {'api_key_id': 'Y4vVzZMBULgSSVuAxf...
# 12  {'default': {'api_key_id': 'u3SzzZMBULgSSVuAba...
# 13  {'default': {'api_key_id': 'G0FFgJMBaHhpeRYTiK...
# 14  {'default': {'api_key_id': 'sLSEYJMBWkMK-slTPU...
# 15  {'default': {'api_key_id': 'X618YJMBWkMK-slTWt...
# 16  {'default': {'api_key_id': '76t6YJMBWkMK-slTHd...
# 17  {'default': {'api_key_id': '7hrEX5MBWkMK-slTYQ...
# 18  {'default': {'api_key_id': 'QhnEX5MBWkMK-slTMX...
# 19  {'default': {'api_key_id': '2RnEX5MBWkMK-slTLX...
# 20  {'default': {'api_key_id': 'zhnEX5MBWkMK-slTK3...
# 21  {'default': {'api_key_id': '_tBrX5MBWkMK-slTv1...
# 22  {'default': {'api_key_id': '6LxPX5MBWkMK-slT88...
# 23  {'default': {'api_key_id': '4IrF3ZIBWkMK-slTw7...
# 24  {'default': {'api_key_id': 'Gzp425IBWkMK-slTY3...
# 25  {'default': {'api_key_id': 'TD4C1pIBWkMK-slTH7...
# 26  {'default': {'api_key_id': 'BUZy0JIBWkMK-slTX8...
# 27  {'default': {'api_key_id': '1UZy0JIBWkMK-slTJ5...
# 28  {'default': {'api_key_id': 'XUVx0JIBWkMK-slTvZ...
# 29  {'default': {'api_key_id': 'jkVx0JIBWkMK-slTu5...
# 30  {'default': {'api_key_id': '7EVx0JIBWkMK-slTtp...
# 31  {'default': {'api_key_id': 'X0Vx0JIBWkMK-slTvZ...
# 32  {'default': {'api_key_id': 'vUFn0JIBWkMK-slT1y...
# 33  {'default': {'api_key_id': 'Ze9FqJIBWkMK-slTvQ...
#
#                                            components  \
# 0   [{'id': 'log-default', 'type': 'log', 'status'...
# 1   [{'id': 'endpoint-default', 'type': 'endpoint'...
# 2   [{'id': 'endpoint-default', 'type': 'endpoint'...
# 3   [{'id': 'log-default', 'type': 'log', 'status'...
# 4   [{'id': 'log-default', 'type': 'log', 'status'...
# 5   [{'id': 'endpoint-default', 'type': 'endpoint'...
# 6   [{'id': 'log-default', 'type': 'log', 'status'...
# 7   [{'id': 'endpoint-default', 'type': 'endpoint'...
# 8   [{'id': 'endpoint-default', 'type': 'endpoint'...
# 9   [{'id': 'endpoint-default', 'type': 'endpoint'...
# 10  [{'id': 'log-default', 'type': 'log', 'status'...
# 11  [{'id': 'log-default', 'type': 'log', 'status'...
# 12  [{'id': 'log-default', 'type': 'log', 'status'...
# 13  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 14  [{'id': 'log-default', 'type': 'log', 'status'...
# 15  [{'id': 'journald-default', 'type': 'journald'...
# 16  [{'id': 'log-default', 'type': 'log', 'status'...
# 17  [{'id': 'log-default', 'type': 'log', 'status'...
# 18  [{'id': 'log-default', 'type': 'log', 'status'...
# 19  [{'id': 'log-default', 'type': 'log', 'status'...
# 20  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 21  [{'id': 'log-default', 'type': 'log', 'status'...
# 22  [{'id': 'log-default', 'type': 'log', 'status'...
# 23  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 24  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 25  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 26  [{'id': 'log-default', 'type': 'log', 'status'...
# 27  [{'id': 'log-default', 'type': 'log', 'status'...
# 28  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 29  [{'id': 'system/metrics-default', 'type': 'sys...
# 30  [{'id': 'endpoint-default', 'type': 'endpoint'...
# 31  [{'id': 'log-default', 'type': 'log', 'status'...
# 32  [{'id': 'log-default', 'type': 'log', 'status'...
# 33  [{'id': 'fleet-server-default', 'type': 'fleet...
#
#                                                 agent  \
# 0   {'id': '21d4ce34-c442-48f2-b955-db72e2343dc5',...
# 1   {'id': '104ae1ea-ea4c-41c1-a979-1d506f3a9864',...
# 2   {'id': '9bad562d-1302-47f5-9701-3f2dc5000d97',...
# 3   {'id': 'b1e3552d-333b-4bd0-807a-283d6dd0775d',...
# 4   {'id': 'a4032047-1f3f-481c-97f7-a231d630decb',...
# 5   {'id': 'c6004c8d-f229-4253-854f-f00873780523',...
# 6   {'id': '66849642-4e47-43dc-811e-3ee1d172d521',...
# 7   {'id': '7994e481-049b-4c51-85ca-56d738f68d16',...
# 8   {'id': '678f3380-92e1-460d-b434-67176b7ba949',...
# 9   {'id': '748ae389-a219-4576-8a87-5fbfa2d6a112',...
# 10  {'id': '70ec403d-4860-433f-a588-bb9fb53e927c',...
# 11  {'id': 'f6d93383-b967-4cdc-be20-03db693348ad',...
# 12  {'id': '76f782c1-0903-4e53-b3d7-0b58ba73d4e7',...
# 13  {'id': '983c0a27-c899-412d-86d4-7472fcd41ad8',...
# 14  {'id': '0511a7a0-8795-43b9-9efe-a0d6fdfb978b',...
# 15  {'id': '992cbc5a-9b99-44e5-8900-0073235d450a',...
# 16  {'id': '5c733b06-3b45-4dcf-ae94-2f04254d33dc',...
# 17  {'id': '10e653eb-a7cb-4e28-86f9-661072f6e584',...
# 18  {'id': 'bb110d9b-172e-4dad-9826-380b87ab98e0',...
# 19  {'id': 'f12925b0-2d4e-4fb3-bc65-24ca864db9fb',...
# 20  {'id': '0d8c6ec2-7f93-4ff1-bc0e-63d665cf245d',...
# 21  {'id': 'fa2d50f5-2616-483b-97e9-140ec76f7815',...
# 22  {'id': 'de86d989-13f2-4098-8370-faafc0c7b78b',...
# 23  {'id': 'ab3bf1af-66e5-485f-800e-440c791b71f5',...
# 24  {'id': 'e8f211b2-1e04-47ec-9299-19ca56ae773c',...
# 25  {'id': '5134b9f4-5f41-4989-9d4f-06067dd864ec',...
# 26  {'id': '4cfb7445-f2ff-4074-8f62-2070e14f18cf',...
# 27  {'id': 'dad99fa5-8b19-4654-a18f-711468871996',...
# 28  {'id': 'dd054ef4-f1d2-4d98-ba68-a22dfc1f818a',...
# 29  {'id': 'd3a5b42f-b06b-4aff-a84e-0d385558dd34',...
# 30  {'id': '7382e546-c57b-45bd-a66f-adcc7f0ad4f7',...
# 31  {'id': '94e631b4-9cd5-4f02-b4f3-8588eee78bb5',...
# 32  {'id': '42fd8984-3fda-4d7f-aa62-4f849cace21f',...
# 33  {'id': 'af54000c-c13e-4c6d-9bf8-ed03cd3adc35',...
#
#                                        local_metadata unhealthy_reason  \
# 0   {'elastic': {'agent': {'build.original': '9.0....             None
# 1   {'elastic': {'agent': {'build.original': '9.0....             None
# 2   {'elastic': {'agent': {'build.original': '9.0....             None
# 3   {'elastic': {'agent': {'build.original': '9.0....             None
# 4   {'elastic': {'agent': {'build.original': '9.0....          [other]
# 5   {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 6   {'elastic': {'agent': {'build.original': '9.0....          [other]
# 7   {'elastic': {'agent': {'build.original': '9.0....             None
# 8   {'elastic': {'agent': {'build.original': '9.0....          [other]
# 9   {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 10  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 11  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 12  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 13  {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 14  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 15  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 16  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 17  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 18  {'elastic': {'agent': {'build.original': '9.0....             None
# 19  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 20  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 21  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 22  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 23  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 24  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 25  {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 26  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 27  {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 28  {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 29  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 30  {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 31  {'elastic': {'agent': {'build.original': '9.0....          [other]
# 32  {'elastic': {'agent': {'build.original': '9.0....  [input, output]
# 33  {'elastic': {'agent': {'build.original': '9.0....          [other]
#
#      status namespaces
# 0    online        NaN
# 1    online        NaN
# 2   offline        NaN
# 3    online        NaN
# 4    online        NaN
# 5    online        NaN
# 6    online        NaN
# 7    online        NaN
# 8   offline        NaN
# 9    online        NaN
# 10   online        NaN
# 11   online        NaN
# 12  offline        NaN
# 13   online        NaN
# 14   online        NaN
# 15   online        NaN
# 16   online        NaN
# 17   online        NaN
# 18   online        NaN
# 19   online        NaN
# 20   online        NaN
# 21   online        NaN
# 22   online        NaN
# 23   online        NaN
# 24   online        NaN
# 25   online         []
# 26   online        NaN
# 27   online        NaN
# 28   online        NaN
# 29   online        NaN
# 30   online        NaN
# 31   online        NaN
# 32   online        NaN
# 33   online        NaN
#
# [34 rows x 22 columns]
