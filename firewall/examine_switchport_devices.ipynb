# %%
### Using the firewall's switch controller, retrieve data on connected devices

# %%
from fortigate_methods import FortigateMethods
import requests
import logging
import urllib3
import sys
import os
sys.path.append(os.path.abspath('../vault'))
from vault_methods import VaultMethods

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

logging.basicConfig(format='%(asctime)s %(message)s',
                    datefmt='%m/%d/%Y %I:%M:%S %p',
                    level=logging.INFO)

if __name__ == '__main__':
    vault_session = VaultMethods()
    vault_session.authenticate()
    firewall_token = vault_session.retrieve_firewall_secret()
    logging.info("Retrieving token")
    if firewall_token:
        logging.info("Retrieved firewall token")
        addr = input("Firewall IP/FQDN-> ")
        port = int(input("Firewall interface port-> "))
        firewall_session = FortigateMethods(addr, port, firewall_token)
        valid_token = firewall_session.check_token_validity()
        if valid_token:
            firewall_session.retrieve_switchport_devices()
    else:
        logging.error("Failed to retrieve firewall token")
# Out:
# Enter the Vault FQDN->  vault.internal.subterfuge.biz
# Enter the Vault username->  robert.gaines
# Enter the Vault password->  ········
# 07/21/2025 08:00:32 PM Retrieving token
# 07/21/2025 08:00:32 PM Retrieved firewall token
# Firewall IP/FQDN->  10.128.10.1
# Firewall interface port->  8443
# 07/21/2025 08:00:38 PM Checking the firewall API token's validity
# 07/21/2025 08:00:38 PM Valid token
# 07/21/2025 08:00:38 PM Appliance status: success
# 07/21/2025 08:00:38 PM Established contact with: FG50GSTK24003234
# 07/21/2025 08:00:38 PM Requesting switchport device data
#                   mac port_name         switch_id  vlan_id  port_id  \
# 0   00:05:1b:31:5d:3f    port22  S124FNTF22014862        1       22
# 1   00:50:b6:e3:24:63    port21  S124FNTF22014862        1       21
# 2   2c:cf:67:5c:78:9b    port12  S124FNTF22014862       10       12
# 3   2c:cf:67:73:ad:f3    port11  S124FNTF22014862       10       11
# 4   6c:4b:90:a2:4a:ee     port6  S124FNTF22014862       10        6
# 5   88:ae:dd:04:e6:f5     port1  S124FNTF22014862       10        1
# 6   88:ae:dd:0f:81:97     port2  S124FNTF22014862       10        2
# 7   88:ae:dd:0f:81:cd     port4  S124FNTF22014862       10        4
# 8   90:09:d0:55:d6:67     port3  S124FNTF22014862       10        3
# 9   b8:27:eb:62:c9:03    port10  S124FNTF22014862       10       10
# 10  b8:27:eb:bb:a6:fd     port9  S124FNTF22014862       10        9
# 11  bc:24:11:13:10:9c     port1  S124FNTF22014862       10        1
# 12  bc:24:11:3b:f7:e7     port2  S124FNTF22014862       10        2
# 13  bc:24:11:3d:9d:fe     port1  S124FNTF22014862       10        1
# 14  bc:24:11:40:f5:95     port4  S124FNTF22014862       10        4
# 15  bc:24:11:47:78:19     port4  S124FNTF22014862       10        4
# 16  bc:24:11:51:a5:9f     port2  S124FNTF22014862       10        2
# 17  bc:24:11:69:47:c3     port4  S124FNTF22014862       10        4
# 18  bc:24:11:69:cc:ca     port4  S124FNTF22014862       10        4
# 19  bc:24:11:76:84:ff     port1  S124FNTF22014862       10        1
# 20  bc:24:11:7a:3f:0b     port2  S124FNTF22014862       10        2
# 21  bc:24:11:a5:75:46     port2  S124FNTF22014862       10        2
# 22  bc:24:11:bc:a9:60     port1  S124FNTF22014862       10        1
# 23  bc:24:11:bf:b2:91     port4  S124FNTF22014862       10        4
# 24  bc:24:11:c1:2c:8d     port1  S124FNTF22014862       10        1
# 25  d8:3a:dd:90:ce:3e    port13  S124FNTF22014862       10       13
# 26  dc:a6:32:35:7d:0e    port15  S124FNTF22014862       10       15
# 27  e4:5f:01:2d:c4:d0    port14  S124FNTF22014862       10       14
# 28  00:23:24:f2:45:e6     port7  S124FNTF22014862       20        7
# 29  90:09:d0:55:d6:68     port5  S124FNTF22014862       30        5
# 30  2c:cf:67:51:be:2f     port8  S124FNTF22014862       50        8
# 31  bc:24:11:d4:6e:c0     port2  S124FNTF22014862       50        2
# 32  e4:5f:01:36:f7:34    port19  S124FNTF22014862       60       19
# 33  e4:5f:01:56:e0:50    port16  S124FNTF22014862       60       16
# 34  e4:5f:01:56:f0:d1    port17  S124FNTF22014862       60       17
# 35  e4:5f:01:56:f2:21    port18  S124FNTF22014862       60       18
# 36  74:78:a6:03:ec:40    port20  S124FNTF22014862       70       20
# 37  94:f3:92:6f:0a:d6  internal  S124FNTF22014862     4094        0
#
#     last_seen  vdom
# 0         878  root
# 1        2500  root
# 2          37  root
# 3          37  root
# 4          37  root
# 5          37  root
# 6          37  root
# 7          37  root
# 8          37  root
# 9          37  root
# 10         37  root
# 11         37  root
# 12         37  root
# 13         37  root
# 14         37  root
# 15         37  root
# 16         37  root
# 17         37  root
# 18         37  root
# 19         37  root
# 20         37  root
# 21         37  root
# 22         37  root
# 23         37  root
# 24         37  root
# 25         37  root
# 26         37  root
# 27         37  root
# 28         37  root
# 29         37  root
# 30         37  root
# 31         37  root
# 32         37  root
# 33         37  root
# 34         37  root
# 35         37  root
# 36         37  root
# 37         37  root
